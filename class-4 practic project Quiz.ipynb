# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadafnandood/AI-Python/blob/main/class-4%20practic%20project%20Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
teachername=str("Sir Aneeq")
print(teachername)
marks:int=80
print(marks)

a = "rizwan"
print("Rizwan")

print("Hello World")
print("Hello World")
name: str = "Aneeq"
Age : int=25
is_active :bool=True
print(name)
name="Ameen"
#yahan main variable ko overrite kr rha houn

# Arthematic operators
# Assignment operators
# Logical operators
# comparision operators  ( boolian , or True / False)

# Arthemetic operators + , - , / , x
print(7+5)
print(10-5)
print(10/2)
print(5*2)

num1: int = 5
num2: int = 5
sum : int = num1+num2
print(sum)

sub: int = num1 - num2
print(sub)

div: int = num1 / num2
print(div)

mul: int = num1 * num2
print(mul)

print(8 ** 2)
# exponent print (8 ** 2) 8 ka square 8^2 = 8x8

print(10/2)
print(11/2)

#print(11 // 2) floor division


# print(11 % 2 )  11/2 = 1 lcm jo baki reh jaye
# print(11 % 2)  11 / 2 reminder / modulus

# Assignment operators wo operators houn gy jo kisi ko kuch sonp dain
x: int = 10
x = x + 5
print(x)
# variable ko overwrite bhi kr sakty hain , varible hamary pass value store krta hy.
# assignment operator hy =
x = x + 5
print(x)
# x ki value 10 or isko overwrite krna ho to x = 15 or 20 etc.
# x : int = 15
x = x + 5
print(x)
# x = x - 5
# 15 * 2 = 30
x: int = 15
x = x % 3
print(x)
# 3 Logical Operators
#
# Comparision Operators
 # == (equal)
 # >  (greator than)
 # <   (Less Than)
 # >=  ( grator or equal to)
 # <=  ( less than or equal to)
 # !=  ( not equal to)

# mera pehla operand/value  k braber hy
num1: int = 10
num2: int = 10
print(num1 == num2)
print(10 == 10)
print(num1 == num2)

num1: int = 10
num2: int = 20
print ( num1 > num2)
print(num1 >= num2)
print(num1 <= num2)
print(num1 != num2)

# logical operators
# and operator , on , not operators three types
num1: int = 12
num2: int = 14
print(10 == 10)
print(num1 != num2)
print(num1 <= num2)

num1: int =24
num2: int =18
print(num1-num2)
print(num1*num2)
print(num1+num2)
print(num1^num2)
print(num1%num2)
print(num1 // num2)

# %%
let arr = [
    [10,20,30,40,50],
    ['abc','efg','hij','klm','nop'],
    ['karachi','lahore','Islamabad','quetta']
]




  document.write(`<h3>Main Array [ ${[...arr]}]</h3> <br> `);

let copyArr1 = [...arr[0]]
let copyArr2 = [...arr[1]]
let copyArr3 = [...arr[2]]
document.write(`<h3> Nested Array 1 [${copyArr1}]  </h3>`);
document.write(`<h3> Nested Array 2 [${copyArr2}]  </h3>`);
document.write(`<h3> Nested Array 3 [${copyArr3}]  </h3>`);



document.write(`<h1 style="margin:50px; text-align: center;">Object Clonning From Spread Operator</h1>`)






let obj = {
    infinix:{

        hot10:{
            price : 20000,
            ram : 4,
            rom : 16,
        },

        hot11:{
            price : 21000,
            ram : 4,
            rom : 16,
        },

        hot12:{
            price : 25000,
            ram : 4,
            rom : 28,
        },
    },

    Samsung:{

        j4:{
            price : 25000,
            ram : 4,
            rom : 16,
        },

        note1:{
            price : 26000,
            ram : 6,
            rom : 26,
        },

        note2:{
            price : 30000,
            ram : 6,
            rom : 28,
        },
    },

    iphone:{

        i1:{
            price : 25000,
            ram : 4,
            rom : 16,
        },

        i2:{
            price : 30000,
            ram : 6,
            rom : 26,
        },

        i3:{
            price : 35000,
            ram : 6,
            rom : 28,
        },
    },
}

                document.write(`<h2> Main Object:  ${{...obj}} </h2>`)
                document.write(`<h3> Infinix nested Object 1 : ${{...obj.infinix}}</h3> <br>`)
                document.write(`<h3> Samsung nested Object 2 : ${{...obj.Samsung}}</h3><br>`)
                document.write(`<h3> Iphone nested Object 3 : ${{...obj.iphone}}</h3><br>`)

                document.write(`<h3> Iphone nested Object Price :  ${{...obj}.iphone.i3.price}<br> `);
                document.write(`<h3> Iphone nested Object Ram : ${{...obj}.iphone.i3.ram}<br> `);
                document.write(`<h3> Iphone nested Object Rom  : ${{...obj}.iphone.i3.rom}<br> `);

# %%
1 # string concatenation (aka how to put strings together)
2 # suppose we want to create a string that says "subscribe to _____"
youtuber = input("CodeWithHarry")
print("subscribe to") == (youtuber)
print("subscribe to {}".format(youtuber))


# Ask for YouTuber's name
youtuber = input("Enter YouTuber's name: ")

# Create a subscribe message
subscribe_message = f"Subscribe to {youtuber}!"

# Print the subscribe message
print(subscribe_message)

# %%
 # logical operators
# and , or , not

# and
num1: int = 20
# num: int = 11
# condition
# num1 is greater than 10
# and
# num1 is less than 30
print(num1 > 10 and num1 < 30)

print(num1 > 10 or num1 <40)
k_elec="No K_Electric"
ups= "No ups"
print(k_elec and ups )

k_elec="No K_Electric"
ups= "No ups"
print(k_elec or ups)

k_elec="Yes K_Electric"
ups= "No ups"
print(k_elec or ups)

k_elec="Yes K_Electric"
ups= "No ups"
print(k_elec != ups)



kelectric="no kelectric"
ups="no ups"
print("kelectric== nokelectric or ups!= no ups")

kelectric="YES"
ups="No"
print("kelectric== nokelectric or ups!= no ups")

KE: int = 1
UPS: int= 0
print( KE >= UPS)

KE: int = 1
UPS: int= 0
print(KE <= UPS)
print(UPS == "KE")
print(KE != UPS)

# Ager   Warna    ager barish nai hui to school jaoun ga ye condition hy.
# IF     Else
# programming main true ya false sy on ya off ka kam liya jatahy.
if 2 > 1:
    print("Hello")         #code space ye indentation ky sath likha jaye ga.
    uname = "Sir Sohaib"
    print(uname)
    # programing main aik code likhty usko statment bolty hain.

    num1:int =2
    num2:int =1
    if num1 > num2:
        print("hello")

# %%
print('Hi')
# condition -> True / False
# if False:
#  print("Condition is true")
# else:
  #  print("condition is false")

#if False:
  #  print("Condition is true")
#else:
   # print("condition is false")

num:int = 100
print(num > 0 and num < 100)

#if num > 0 and num < 100:
 #   print(number is positive)

# name:str =="Sir Sohaib":
# if name == "Sir Sohaib":
    # print("Welcome Sir Sohaib")

time_of_day:str = "Good Night"
if time_of_day =="Good Morning":
    print("Good Morning")
elif time_of_day == "Good AfterNoon":
    print("Good AfterNoon")
elif time_of_day == "Good Evening":
    print("Good Evening")
else:
    print("Good Night")

# if , elif , else conditions

# data types , string , integer , boolean , list
# list ky ander aik sy zayada value store kr sakty hain.

name:str = "Sir Aneeq"
#         0         ,    1        ,   2  , index hamesha 0 sy start hota hy.
names: list = ["Sir Aneeq","Sir Sohaib", "Sir Ali"]
print(names)
print(names[2])

# har value ky baad koma , istamal karain gy  jo value ko saperate krta hy.

numbers : list [int] = [0,1,2,3,4,5]
range(0,5) #0,1,2,3,4
print(range(5))
res = range(5)
print(res)


# starting point
# condition
# increment

range(0,5)
print(*range(0,5))

numbers : list [int] = [0,1,2,3,4,5]
print(numbers[1])
print(numbers[2])
print(numbers[3])
print(numbers[4])
print(numbers[5])

# for loop   , jis kam ko bar bar krna ho wo loop sy kraty hain jaisy bottle bar kr fridge man rakh rahy hain.
# loop interabsle sy chalta hy

for num in numbers:
        print("num is",num)
# num ki value add ho jati hy loop itrable sy chalta hy

# first assignment ail date sheet bnani hy aur garding system dena hy .
# if  1st ,elif pass  , elis fail
# 2 2ka table bnana hy

# %%
import calendar
yy = 2025 # year
mm = 2 # Month
# display the calendar
print(calendar.month(yy,mm))

import calendar
yy = 2025 # year
mm = 1 # Month
# display the calendar
print(calendar.month(yy,mm))

# %%
if (3>2) > 1:
    print("True")
else:
    print("False")
# A) True           B) False
# C) Error          D) None
