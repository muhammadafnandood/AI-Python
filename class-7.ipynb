# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadafnandood/AI-Python/blob/main/class-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # # data types sting , integer, boolean , float, list,
# # my_dict = {
# #     "Afnan":1006,
# #     "Ali":10080,
# #     "Fatima":10089
# #     }
# #             # Key : Value
# # print(my_dict)
# # print(my_dict["Ali"])

# # contact =["ali",109]

# # Data Types ,
# #
# # 1. String
# # 2. Integer
# # 3. Boolean
# # 4. List
# # 5. tuple
# # 6. Dictionary
# # student = {
# #     "Name": "Ali",
# #     "Age":20,
# #     "Class":"Sunday 7-10"
# # }
# # student["Name"]
# # print("Name")
# # print("Name")

# # print("Before",student)
# # student["RollNo"] = 9897

# # print("After",student)

# # Create a dictionary
# # person = {
# #     "name": "Ali",
# #     "age": 25,
# #     "city": "Karachi"
# # }

# # # Access values using keys
# # print(person["name"])  # Output: Ali
# # print(person["age"])   # Output: 25



# # def charger():          # Basic Function ka matlib aik nokar ya mulazim etc.
# #     print("Charge Mobile")
# # charger()

# Static function,
# # def ramokaka():
# #     print("ramokaka biryani banao")
# # ramokaka()



# a = 1
# b = 4

# # def add():
# #     return a+b
# #     sum = add()
# #     print(sum)
# # add()


# def ramokaka():
#     return"biryani ban gai"   #return ky baad koi kam nai kary ga function,
# plate = ramokaka()
# print(plate)
# ramokaka()

                        # round bracket ky ander jo bhi likhty hain usko perameter kehty hain.
def greet(name,age):            # main chahta houn ky har aik ky sath unky name ky sath salam kary,
    print("Asslam o Alaikum Sir",name,"Your age is",age)
 # argument ali
greet("Ali",20)





#  Add ka function bana hy
# version 1  Static Function
num1: int = 10
num2: int = 10

def addition():
    print(num1+num2)
addition()


# version 2 Dynamic function


def addition(num1:int, num2:int):
    print(num1+num2)
addition(10,10)


# version 3 Dynamic function    ,


def addition(num1:int, num2:int):
    return num1+num2
print(addition(10,10))


result = addition(10,10)
print(result)
# final result = 20+20
final_result = result / 20
print(final_result)
